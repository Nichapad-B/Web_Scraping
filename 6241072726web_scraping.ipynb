# %% [markdown]
# ### ชื่อ-นามสกุล : ณิชาภัทร บุญพาวัฒนา
# ### รหัสนิสิต : 6241072726

# %% [markdown]
# Data Source : https://www.homepro.co.th/c/APP0904

# %%
# import packages and module
import pandas as pd
import requests
from bs4 import BeautifulSoup
from PIL import Image
import io

# %%
print(f'pandas version = {pd.__version__}')
# Out:
# pandas version = 1.3.5

# %% [markdown]
# ### Web scraping

# %%
url = 'https://www.homepro.co.th/c/APP0904'
r=requests.get(url)

# %%
r.text[:200]
# Out:
# '\n<!doctype html>\n<html>\n<head>\n<title>ตู้เย็น 1 ประตู&nbsp;ตู้เย็นเล็ก ตู้เย็นมินิ ตู้เย็นมินิบาร์ ตู้เย็นขนาดเล็ก | Homepro Online</title>\n<meta charset="UTF-8" />\n<meta name="description" content="ต'

# %%
s=BeautifulSoup(r.text, 'lxml')
type(s)
# Out:
# bs4.BeautifulSoup

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    ตู้เย็น 1 ประตู ตู้เย็นเล็ก ตู้เย็นมินิ ตู้เย็นมินิบาร์ ตู้เย็นขนาดเล็ก | Homepro Online
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="ตู้เย็น 1 ประตู ตู้เย็นเล็ก ตู้เย็นมินิ ตู้เย็นมินิบาร์ ยี่ห้อดัง Hitachi, Mitsubishi, Toshiba, Samsung ตู้เย็นเล็กประหยัดไฟ ตู้เย็น 1 ประตูทันสมัย ราคาถูก คุณภาพดี ซื้อตู้เย็นเล็กออนไลน์ HomePro Online" name="description"/>
#   <meta content="One-Door Refrigerators, ตู้เย็น 1 ประตู , ตู้เย็นมินิบาร์ , ตู้เย็นมินิ" name="keywords"/>
#   <meta content="width=1280" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="website" property="og:type"/>
#   <meta content="ตู้เย็น 1 ประตู ตู้เย็นเล็ก ตู้เย็นมินิ ตู้เย็นมินิบาร์ ตู้เย็นขนาดเล็ก | Homepro Online" property="og:title"/>
# ...

# %%
all_products = s.select('div.hp-card-product-plp')
all_products
# Out:
# [<div class="hp-card-product-plp" data-value="1154314" id="product-1154314">
#  <a href="https://www.homepro.co.th/p/1154314">
#  <div class="hp-card-product-plp-link">
#  <div class="image">
#  <img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" style="width:160px;height:160px;object-fit:contain;border:none;" title="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน"/>
#  </div>
#  <div class="img-tag-left">
#  </div>
#  <div class="img-tag-right" style="display:none;">
#  <img src="https://static.homepro.co.th/assets/images/plp/3_3.png" style="max-width:60px;height:auto;object-fit:contain;border:none;"/>
#  </div>
#  <div class="discount-tag-right">12%</div>
#  </div>
#  </a>
#  <div class="icon-container-promo">
#  </div>
#  <div class="sku-container">
#  <div class="sku-row">
#  <span class="sku">
#  SKU: 1154314
#  </span>
#  <div class="icon-tag-right">
# ...

# %%
print(all_products[0].prettify())
# Out:
# <div class="hp-card-product-plp" data-value="1154314" id="product-1154314">
#  <a href="https://www.homepro.co.th/p/1154314">
#   <div class="hp-card-product-plp-link">
#    <div class="image">
#     <img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" style="width:160px;height:160px;object-fit:contain;border:none;" title="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน"/>
#    </div>
#    <div class="img-tag-left">
#    </div>
#    <div class="img-tag-right" style="display:none;">
#     <img src="https://static.homepro.co.th/assets/images/plp/3_3.png" style="max-width:60px;height:auto;object-fit:contain;border:none;"/>
#    </div>
#    <div class="discount-tag-right">
#     12%
#    </div>
#   </div>
#  </a>
#  <div class="icon-container-promo">
#  </div>
#  <div class="sku-container">
#   <div class="sku-row">
#    <span class="sku">
#     SKU: 1154314
#    </span>
# ...

# %%
all_products[0].find('img')['src']
# Out:
# 'https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg'

# %%
all_products[0].select_one('a')['href']
# Out:
# 'https://www.homepro.co.th/p/1154314'

# %%
# t = all_products[0]

r=requests.get(all_products[0].select_one('img')['src'])
img = Image.open(io.BytesIO(r.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x160 at 0x257E2D18EE0>

# %%
# link ของรูปในเว็บไซต์
pic = []
for e in all_products:
    prod_img=e.select_one('img')['src']
    pic.append(prod_img)
    
pic[:3]
# Out:
# ['https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg',
#  'https://cdn.homepro.co.th/ART_IMAGE/10/767/1076749/160x160/10072021_1076749$Imagec1.jpg',
#  'https://cdn.homepro.co.th/ART_IMAGE/11/542/1154215/160x160/10072021_1154215$Imagec1.jpg']

# %%
all_products
# Out:
# [<div class="hp-card-product-plp" data-value="1154314" id="product-1154314">
#  <a href="https://www.homepro.co.th/p/1154314">
#  <div class="hp-card-product-plp-link">
#  <div class="image">
#  <img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" style="width:160px;height:160px;object-fit:contain;border:none;" title="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน"/>
#  </div>
#  <div class="img-tag-left">
#  </div>
#  <div class="img-tag-right" style="display:none;">
#  <img src="https://static.homepro.co.th/assets/images/plp/3_3.png" style="max-width:60px;height:auto;object-fit:contain;border:none;"/>
#  </div>
#  <div class="discount-tag-right">12%</div>
#  </div>
#  </a>
#  <div class="icon-container-promo">
#  </div>
#  <div class="sku-container">
#  <div class="sku-row">
#  <span class="sku">
#  SKU: 1154314
#  </span>
#  <div class="icon-tag-right">
# ...

# %%
lst1=[]
lst2=[]
lst3=[]

for e in all_products:
    lst1.append(e.select_one('img')['alt'])
    lst2.append(e.select_one('img')['src'])
    lst3.append(e.select_one('a')['href'])

# %%
lst3[:3]
# Out:
# ['https://www.homepro.co.th/p/1154314',
#  'https://www.homepro.co.th/p/1076749',
#  'https://www.homepro.co.th/p/1154215']

# %%
p = []
for e in all_products:
    price1 = e.find('div', {'class': 'product-info-container'}).find('span', 'reduced-price')
    if price1 is not None:
        p.append(price1.get_text())
    elif price1 is None:
        price2 = e.find('div', {'class': 'product-info-container'}).find('div', 'original-price')        
        if price2 is not None:
            p.append(price2.get_text())

# %%
p
# Out:
# ['5,290 บาท',
#  '4,090 บาท',
#  '5,190 บาท',
#  '4,690 บาท',
#  '5,690 บาท',
#  '5,990 บาท',
#  '5,990 บาท',
#  '3,990 บาท',
#  '6,690 บาท',
#  '5,490 บาท',
#  '6,490 บาท',
#  '4,590 บาท',
#  '4,390 บาท',
#  '6,690 บาท',
#  '6,490 บาท',
#  '6,290 บาท',
#  '4,690 บาท',
#  '3,590 บาท',
#  '3,590 บาท',
#  '6,490 บาท',
#  '6,490 บาท',
#  '6,290 บาท',
#  '6,290 บาท',
#  '6,190 บาท',
#  '6,190 บาท',
#  '5,890 บาท',
#  '5,390 บาท',
#  '4,690 บาท',
#  '4,590 บาท',
#  '4,490 บาท',
#  '4,390 บาท',
#  '5,490 บาท',
#  '65,900 บาท',
#  '105,000 บาท',
#  '3,290 บาท',
#  '5,190 บาท',
#  '5,590 บาท',
#  '5,990 บาท',
#  '65,900 บาท',
#  '5,990 บาท',
#  '105,000 บาท',
#  '5,490 บาท',
#  '6,690 บาท',
#  '4,290 บาท',
#  '6,190 บาท',
#  '5,790 บาท',
#  '5,190 บาท',
#  '35,900 บาท',
#  '3,790 บาท',
#  '5,990 บาท',
#  '2,990 บาท',
#  '6,290 บาท']

# %%
d = []
for e in all_products:
    discount = e.find('div', {'class': 'product-info-container'}).find('div', 'online-discount')
    if discount is not None:
        d.append(discount.get_text())
    else:
        d.append(discount)

d[:5]
# Out:
# ['\nซื้อออนไลน์ ลดเพิ่ม 500 บาท\n',
#  '\nซื้อออนไลน์ ลดเพิ่ม 409 บาท\n',
#  '\nซื้อออนไลน์ ลดเพิ่ม 400 บาท\n',
#  None,
#  '\nซื้อออนไลน์ ลดเพิ่ม 400 บาท\n']

# %%
# รวม List เพื่อจะสร้างเป็น DataFrame
j = list(zip(lst1, lst2, lst3, p, d))

# %% [markdown]
# ### Convert to DataFrame

# %%
pd.options.display.max_colwidth = 0

# %%
df=pd.DataFrame(j, columns=['prod_name', 'img_url', 'link', 'price', 'discount'])
df.head()
# Out:
#                                               prod_name  \
# 0  ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน
# 1  ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส
# 2  ตู้เย็น 1 ประตู TOSHIBA GR-D149 5.2 คิว สีเงิน
# 3  ตู้เย็น 1 ประตู TOSHIBA GR-D906MG 3.1 คิว สีดำ
# 4  ตู้เย็น 1 ประตู MITSUBISHI MR-140S/SL 4.8 คิว สีเงิน
#
#                                                                                    img_url  \
# 0  https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg
# 1  https://cdn.homepro.co.th/ART_IMAGE/10/767/1076749/160x160/10072021_1076749$Imagec1.jpg
# 2  https://cdn.homepro.co.th/ART_IMAGE/11/542/1154215/160x160/10072021_1154215$Imagec1.jpg
# 3  https://cdn.homepro.co.th/ART_IMAGE/11/897/1189797/160x160/27122021_1189797$Imagec1.jpg
# 4  https://cdn.homepro.co.th/ART_IMAGE/11/903/1190314/160x160/12012022_1190314$Imagec1.jpg
#
#                                   link      price  \
# ...

# %%
df['discount'] = df['discount'].str.replace(r'\nซื้อออนไลน์ ลดเพิ่ม', '', regex=True)
df['discount'] = df['discount'].str.replace(r'บาท\n', '', regex=True)
df['price'] = df['price'].str.replace(r'บาท', '', regex=True)
df['price'] = df['price'].str.replace(r',', '', regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   prod_name  52 non-null     object
#  1   img_url    52 non-null     object
#  2   link       52 non-null     object
#  3   price      52 non-null     object
#  4   discount   13 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %%
df['discount'].fillna(value=0, inplace=True)
df['discount'] = df['discount'].astype(float)
df['price'] = df['price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   prod_name  52 non-null     object
#  1   img_url    52 non-null     object
#  2   link       52 non-null     object
#  3   price      52 non-null     float64
#  4   discount   52 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 2.2+ KB

# %%
df['net_price'] = df['price']-df['discount']

# %%
df.head()
# Out:
#                                               prod_name  \
# 0  ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน
# 1  ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส
# 2  ตู้เย็น 1 ประตู TOSHIBA GR-D149 5.2 คิว สีเงิน
# 3  ตู้เย็น 1 ประตู TOSHIBA GR-D906MG 3.1 คิว สีดำ
# 4  ตู้เย็น 1 ประตู MITSUBISHI MR-140S/SL 4.8 คิว สีเงิน
#
#                                                                                    img_url  \
# 0  https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg
# 1  https://cdn.homepro.co.th/ART_IMAGE/10/767/1076749/160x160/10072021_1076749$Imagec1.jpg
# 2  https://cdn.homepro.co.th/ART_IMAGE/11/542/1154215/160x160/10072021_1154215$Imagec1.jpg
# 3  https://cdn.homepro.co.th/ART_IMAGE/11/897/1189797/160x160/27122021_1189797$Imagec1.jpg
# 4  https://cdn.homepro.co.th/ART_IMAGE/11/903/1190314/160x160/12012022_1190314$Imagec1.jpg
#
#                                   link   price  discount  net_price
# ...

# %% [markdown]
# ### Convert to HTML

# %%
from IPython.display import HTML

# %%
def to_html_img(url, alt=None, width=100):
    if alt==None:
        alt=''
    return f'<img alt="{alt}" src="{url}" width="{width}"/>'

# %%
df['img']=df.apply(lambda r: to_html_img(r['img_url'], r['prod_name'], 100), axis=1)

# %%
df.head()
# Out:
#                                               prod_name  \
# 0  ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน
# 1  ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส
# 2  ตู้เย็น 1 ประตู TOSHIBA GR-D149 5.2 คิว สีเงิน
# 3  ตู้เย็น 1 ประตู TOSHIBA GR-D906MG 3.1 คิว สีดำ
# 4  ตู้เย็น 1 ประตู MITSUBISHI MR-140S/SL 4.8 คิว สีเงิน
#
#                                                                                    img_url  \
# 0  https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg
# 1  https://cdn.homepro.co.th/ART_IMAGE/10/767/1076749/160x160/10072021_1076749$Imagec1.jpg
# 2  https://cdn.homepro.co.th/ART_IMAGE/11/542/1154215/160x160/10072021_1154215$Imagec1.jpg
# 3  https://cdn.homepro.co.th/ART_IMAGE/11/897/1189797/160x160/27122021_1189797$Imagec1.jpg
# 4  https://cdn.homepro.co.th/ART_IMAGE/11/903/1190314/160x160/12012022_1190314$Imagec1.jpg
#
#                                   link   price  discount  net_price  \
# ...

# %%
HTML(df[:5][['prod_name', 'img']].to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>prod_name</th>
#       <th>img</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน</td>
#       <td><img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" width="100"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส</td>
#       <td><img alt="ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส" src="https://cdn.homepro.co.th/ART_IMAGE/10/767/1076749/160x160/10072021_1076749$Imagec1.jpg" width="100"/></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ตู้เย็น 1 ประตู TOSHIBA GR-D149 5.2 คิว สีเงิน</td>
# ...

# %%
def to_html_a(url, text):
    if text==None:
        text=''
    return f'<a href="{url}">{text}</a>'

# %%
df['name_link']=df.apply(lambda r: to_html_a(r['link'], r['prod_name']), axis=1)

# %%
df.head()
# Out:
#                                               prod_name  \
# 0  ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน
# 1  ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส
# 2  ตู้เย็น 1 ประตู TOSHIBA GR-D149 5.2 คิว สีเงิน
# 3  ตู้เย็น 1 ประตู TOSHIBA GR-D906MG 3.1 คิว สีดำ
# 4  ตู้เย็น 1 ประตู MITSUBISHI MR-140S/SL 4.8 คิว สีเงิน
#
#                                                                                    img_url  \
# 0  https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg
# 1  https://cdn.homepro.co.th/ART_IMAGE/10/767/1076749/160x160/10072021_1076749$Imagec1.jpg
# 2  https://cdn.homepro.co.th/ART_IMAGE/11/542/1154215/160x160/10072021_1154215$Imagec1.jpg
# 3  https://cdn.homepro.co.th/ART_IMAGE/11/897/1189797/160x160/27122021_1189797$Imagec1.jpg
# 4  https://cdn.homepro.co.th/ART_IMAGE/11/903/1190314/160x160/12012022_1190314$Imagec1.jpg
#
#                                   link   price  discount  net_price  \
# ...

# %%
HTML(df[:5][['prod_name', 'img', 'name_link']].to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>prod_name</th>
#       <th>img</th>
#       <th>name_link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน</td>
#       <td><img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" width="100"/></td>
#       <td><a href="https://www.homepro.co.th/p/1154314">ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส</td>
#       <td><img alt="ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส" src="https://cdn.homepro.co.th/ART_IMAGE/10/767/1076749/160x160/10072021_1076749$Imagec1.jpg" width="100"/></td>
# ...

# %%
df['img_link']=df.apply(lambda r: to_html_a(r['link'], r['img']), axis=1)

# %%
HTML(df[:5][['prod_name', 'img', 'name_link', 'img_link']].to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>prod_name</th>
#       <th>img</th>
#       <th>name_link</th>
#       <th>img_link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน</td>
#       <td><img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" width="100"/></td>
#       <td><a href="https://www.homepro.co.th/p/1154314">ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน</a></td>
#       <td><a href="https://www.homepro.co.th/p/1154314"><img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" width="100"/></a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส</td>
# ...

# %%
d_html = HTML(df[:5][['name_link', 'img_link', 'net_price']].to_html(escape=False))
d_html
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name_link</th>
#       <th>img_link</th>
#       <th>net_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="https://www.homepro.co.th/p/1154314">ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน</a></td>
#       <td><a href="https://www.homepro.co.th/p/1154314"><img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" width="100"/></a></td>
#       <td>4790.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="https://www.homepro.co.th/p/1076749">ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส</a></td>
# ...

# %% [markdown]
# ### Convert to Excel

# %%
df.to_excel('web_scraping.xlsx')

# %%
d_excel = df[['prod_name', 'img', 'link', 'net_price']]

# %%
d_excel.head()
# Out:
#                                               prod_name  \
# 0  ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน
# 1  ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส
# 2  ตู้เย็น 1 ประตู TOSHIBA GR-D149 5.2 คิว สีเงิน
# 3  ตู้เย็น 1 ประตู TOSHIBA GR-D906MG 3.1 คิว สีดำ
# 4  ตู้เย็น 1 ประตู MITSUBISHI MR-140S/SL 4.8 คิว สีเงิน
#
#                                                                                                                                                                            img  \
# 0  <img alt="ตู้เย็น 1 ประตู TOSHIBA GR-D189 6.4 คิว สีเงิน" src="https://cdn.homepro.co.th/ART_IMAGE/11/543/1154314/160x160/10072021_1154314$Imagec1.jpg" width="100"/>
# 1  <img alt="ตู้เย็น 1 ประตู ELECTROLUX EUM0500SB 1.6 คิว สเตนเลส" src="https://cdn.homepro.co.th/ART_IMAGE/10/767/1076749/160x160/10072021_1076749$Imagec1.jpg" width="100"/>
# ...

# %%
d_excel.to_excel('web_scraping2.xlsx')
